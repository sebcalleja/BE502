# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/sebastiancalleja/Desktop/tucson_rain.csv')

# %%
def get_rain(data, year=None, month=None, day=None, quality=None,
              date_col="readingDate", quality_col="quality", rain_col="rainAmount"):
    if year !=None:
        data=data[data[date_col].str.contains(str(year)+"-")]
    if month !=None and year !=None:
        month_str = "%02d" %month
        data=data[data[date_col].str.contains(str(year)+ "-" + month_str+ "-")]
    if day !=None and month !=None and year !=None:
        day_str = "%02d" %day
        data=data[data[date_col].str.contains(str(year)+ "-" + month_str + "-" + day_str)]
    return data[rain_col].sum()

# %%
def get_gauge(data, year=None, month=None, day=None, quality=None,
              date_col="readingDate", quality_col="quality", gauge_col="gaugeId"):
    if year !=None:
        data=data[data[date_col].str.contains(str(year)+"-")]
    if month !=None and year !=None:
        month_str = "%02d" %month
        data=data[data[date_col].str.contains(str(year)+ "-" + month_str+ "-")]
    if day !=None and month !=None and year !=None:
        day_str = "%02d" %day
        data=data[data[date_col].str.contains(str(year)+ "-" + month_str + "-" + day_str)]
    return data[gauge_col].count()

# %%
def get_gauge1(data, year=None, month=None, day=None, quality=None,
              date_col="readingDate", quality_col="quality", gauge_col="gaugeId"):
    if year !=None:
        data=data[data[date_col].str.contains(str(year)+"-")]
    if month !=None and year !=None:
        month_str = "%02d" %month
        data=data[data[date_col].str.contains(str(year)+ "-" + month_str+ "-")]
    if day !=None and month !=None and year !=None:
        day_str = "%02d" %day
        data=data[data[date_col].str.contains(str(year)+ "-" + month_str + "-" + day_str)]
    return data[gauge_col].to_list()

# %%
def get_gauge2(data, year2=None, month2=None, day2=None, quality=None,
              date_col="readingDate", quality_col="quality", gauge_col="gaugeId"):
    if year2 !=None:
        data=data[data[date_col].str.contains(str(year2)+"-")]
    if month2 !=None and year2 !=None:
        month_str = "%02d" %month2
        data=data[data[date_col].str.contains(str(year2)+ "-" + month_str+ "-")]
    if day2 !=None and month2 !=None and year2 !=None:
        day_str = "%02d" %day2
        data=data[data[date_col].str.contains(str(year2)+ "-" + month_str + "-" + day_str)]
    return data[gauge_col].to_list()

# %%
def test(data, year=None, month=None, day=None, quality=None, 
        date_col="readingDate", quality_col="quality", gauge_col="gaugeId", rain_col="rainAmount"):
    def get_rain():
        def get_gauge(): 
            return data[gauge_col].count()
        return data[rain_col].sum()
    return get_rain()

# %%
def test2 (data, year=None, month=None, day=None, year2=None, month2=None, day2=None,
          quality=None, date_col="readingDate", quality_col="quality", gauge_col="gaugeId"):
    def get_gauge1():
        def get_gauge2():
            return data[gauge_col].to_list()
        return data[gauge_col].to_list()
    return get_gauge1(), get_gauge2(data)

# %%
test2(data, 2019, 1, 1, 2018, 1, 1, quality="Good")
# Out:
# ([2348,
#   8062,
#   3161,
#   3075,
#   5812,
#   178,
#   7913,
#   1409,
#   1254,
#   3017,
#   6308,
#   117,
#   1722,
#   196,
#   162,
#   1725,
#   6555,
#   6449,
#   1040,
#   8575,
#   8974,
#   10353,
#   4173,
#   9594,
#   6357,
#   860,
#   5662,
#   184,
#   103,
#   5523,
#   6149,
#   2011,
#   1213,
#   5166,
#   4419,
#   1399,
#   203,
#   1728,
#   4317,
#   231,
#   145,
#   760,
#   142,
#   20,
#   6444,
#   122,
#   3160,
#   10441,
#   417,
#   1499,
#   2813,
#   1229,
#   493,
#   450,
#   10462,
#   166,
#   80,
#   10396,
#   6267,
#   3203,
#   3395,
#   3076,
#   129,
#   209,
#   5281,
#   317,
#   6121,
#   9427,
#   3271,
#   116,
#   10400,
#   135,
#   10475,
#   419,
#   1303,
#   497,
#   3057,
#   7529,
#   8626,
#   9354,
#   1701,
#   9277,
#   5932,
#   4624,
#   313,
#   1589,
#   3393,
#   9053,
#   5287,
#   2998,
#   978,
#   5262,
#   6225,
#   4474,
#   5325,
#   10386,
#   6538,
#   10435,
#   6017,
#   5641,
#   1854,
#   10013,
# ...

# %%
# Out:
# '/Users/sebastiancalleja/Documents/Coding Stuff'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-ad8b05bb6e97> in <module>
# ----> 1 print(res(data))
#
# TypeError: 'numpy.float64' object is not callable
